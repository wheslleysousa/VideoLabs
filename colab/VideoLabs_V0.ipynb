# %% [markdown]
# # VideoLabs V0
# Monte seu Google Drive e gere todas as combinações com FFmpeg.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt-get -qq update && apt-get -qq install -y ffmpeg git
# !rm -rf /content/videolabs
# !git clone https://github.com/wheslleysousa/VideoLabs.git /content/videolabs

# %%
# Altere somente estas duas linhas se necessário
PROJECT = '/content/drive/MyDrive/VideoLabs/input/Projeto01'
OUTPUT = '/content/drive/MyDrive/VideoLabs/output/Projeto01'

# !python /content/videolabs/videolabs.py "{PROJECT}" --output "{OUTPUT}"
